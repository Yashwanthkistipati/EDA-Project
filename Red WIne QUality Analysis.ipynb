# %%
## importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
##returns description of the data in the DataFrame
df.describe()
##As we can see here, mean value is less than the median value of each column.
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Add the color column
df['color'] = 'red'
df['color2'] = 'white'

# %%
## it will print first five coloumns
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color color2
# 0      9.4        5   red  white
# ...

# %%
## it will print last five coloumns
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality color color2
# ...

# %%
##check how many null values are present in the data set
df.isnull().sum()
## there are no nul values
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# color2                  0
# dtype: int64

# %%
## it will say how many rows and columns are there 
df.shape
# Out:
# (1599, 14)

# %%
## it will say how many duplicte values are there
df.duplicated().sum()
# Out:
# 240

# %%
## returns the number of unique values for each column
df.quality.nunique()
# Out:
# 6

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
## function is used to split the data into groups based on some criteria
df.groupby(['quality','color2'],as_index= False).mean()
# Out:
#    quality color2  fixed acidity  volatile acidity  citric acid  \
# 0        3  white       8.360000          0.884500     0.171000
# 1        4  white       7.779245          0.693962     0.174151
# 2        5  white       8.167254          0.577041     0.243686
# 3        6  white       8.347179          0.497484     0.273824
# 4        7  white       8.872362          0.403920     0.375176
# 5        8  white       8.566667          0.423333     0.391111
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0        2.635000   0.122500            11.000000             24.900000
# 1        2.694340   0.090679            12.264151             36.245283
# 2        2.528855   0.092736            16.983847             56.513950
# 3        2.477194   0.084956            15.711599             40.869906
# 4        2.720603   0.076588            14.045226             35.020101
# 5        2.577778   0.068444            13.277778             33.444444
#
# ...

# %%
# Find the mean quality of each wine type with groupby
df.groupby('color').mean().quality
# Out:
# color
# red    5.636023
# Name: quality, dtype: float64

# %%
df.describe().pH
# Out:
# count    1599.000000
# mean        3.311113
# std         0.154386
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.72, 3.11, 3.21, 3.32, 4.01]

# %%
values_count = df.quality.value_counts()
values_count
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
# Labels for the four acidity level groups
bin_names = ['high', 'mod_high', 'medium', 'low'] # Name each acidity level category

# %%
# Creates acidity_levels column
df['acidity_levels'] = pd.cut(df['pH'], bin_edges, labels=bin_names)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  color acidity_levels
# 0      9.4        5  white            low
# ...

# %%
df.groupby('acidity_levels').mean().quality
# Out:
# acidity_levels
# high        5.692308
# mod_high    5.676157
# medium      5.670429
# low         5.588798
# Name: quality, dtype: float64

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(7,7))
plt.pie(values_count,autopct='%1.1f%%',textprops={'fontsize':14})
plt.legend([5,6,7,4,8,3])
plt.show()

# %%
df.hist(bins=25,figsize=(10,10),color='green')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(df['quality'],df['alcohol'],color='green')
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()

# %%
sns.histplot(df.quality,color='green',binwidth=0.9)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Count'>

# %% [markdown]
# #### Hence by seeing the above we can say that wine quality is approximately normally distributed.

# %%
sns.histplot(df.pH,color='green')
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Count'>

# %% [markdown]
# #### the quantity of PH is normally distributed for few outliers

# %%
sns.histplot(df['fixed acidity'],color='green')
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Count'>

# %% [markdown]
# #### There are many outliers with high residual sugar and the distribution is skewed right.

# %%
sns.histplot(df['chlorides'],color='green')
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Count'>

# %% [markdown]
# #### As we see that Chloride distribution is skewed right  with outliers

# %%
sns.histplot(df['total sulfur dioxide'],color='green')
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Count'>

# %%
sns.histplot(df['free sulfur dioxide'],color='green')
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Count'>

# %% [markdown]
# #### Distribution for free sulfur dioxide and total sulfur dioxide is skewed right.

# %%
sns.histplot(df['sulphates'],color='green')
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Count'>

# %% [markdown]
# #### Distribution for sulphates is skewed right with some outliers

# %%
sns.histplot(df['alcohol'],color='green')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# ## Heat Map

# %%
## it shows correlation between different features
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),color = "k", annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color', 'acidity_levels'],
#       dtype='object')

# %%
##it shows quality of the wine from the data
sns.countplot(x='quality', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# ## Relation Between Fixed Acidity and Quality

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(x= "quality", y="fixed acidity" , data = df) 
plt.title('fixed acidity and quality')
# Out:
# Text(0.5, 1.0, 'fixed acidity and quality')

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="quality", y="fixed acidity", data = df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
df.groupby('quality')['fixed acidity'].mean().plot.line()
plt.ylabel("fixed acidity")
# Out:
# Text(0, 0.5, 'fixed acidity')

# %% [markdown]
# ## Relation Between Volatile acidity and Quality

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="quality", y="volatile acidity", data = df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
df.groupby('quality')['volatile acidity'].mean().plot.line()
plt.ylabel("volatile acidity")
# Out:
# Text(0, 0.5, 'volatile acidity')

# %% [markdown]
# ## Relation Between Quality And Sulphates

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="quality", y="sulphates", data = df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
df.groupby('quality')['sulphates'].mean().plot.line()
plt.ylabel("sulphates")
# Out:
# Text(0, 0.5, 'sulphates')

# %%
sns.boxplot(x="quality", y="sulphates", data = df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %% [markdown]
# ## Realtion Between Quality And PH

# %%
sns.boxplot(x="quality", y="pH", data = df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
df.groupby('quality')['pH'].mean().plot.line()
plt.ylabel("pH")
# Out:
# Text(0, 0.5, 'pH')

# %% [markdown]
# ## Realtion between fixed acidity and pH

# %%
sns.lmplot(x="fixed acidity", y="pH", data = df)

# %% [markdown]
# ## Realtion between fixed acidity and citric acid

# %%
sns.lmplot(y="fixed acidity", x="citric acid", data = df)

# %% [markdown]
# ## checking outliers

# %%
##Outliers are the points outside the 1.5×IQR or more above the third quartile or 1.5×IQR or more below the first quartile.
##Except for alcohol,all other features have outliers.
plt.figure(figsize=(10,15))
for i,col in enumerate(list(df.columns.values)):
    plt.subplot(4,3,i+1)
    df.boxplot(col)
    plt.grid()
    plt.tight_layout
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16312/2009627581.py in <module>
#       3 plt.figure(figsize=(10,15))
#       4 for i,col in enumerate(list(df.columns.values)):
# ----> 5     plt.subplot(4,3,i+1)
#       6     df.boxplot(col)
#       7     plt.grid()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
# ...

# %%
df.plotting.scatter_matrix(data.loc[:, "citric acid":"sulphates"], diagonal="quality.factor",figsize=(20,15))
plt.show()

# %% [markdown]
# ## Pair plot:

# %%
sns.pairplot(df)

# %% [markdown]
# ## Violinplot:

# %%
sns.violinplot(x='quality', y='alcohol', data=df)
